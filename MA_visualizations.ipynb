# %%
# !pip install umap-learn
# Out:
# Collecting umap-learn
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\paolo\anaconda3\lib\site-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in c:\users\paolo\anaconda3\lib\site-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\paolo\anaconda3\lib\site-packages (from umap-learn) (1.5.1)
# Requirement already satisfied: numba>=0.51.2 in c:\users\paolo\anaconda3\lib\site-packages (from umap-learn) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm in c:\users\paolo\anaconda3\lib\site-packages (from umap-learn) (4.66.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\paolo\anaconda3\lib\site-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\paolo\anaconda3\lib\site-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\paolo\anaconda3\lib\site-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Requirement already satisfied: colorama in c:\users\paolo\anaconda3\lib\site-packages (from tqdm->umap-learn) (0.4.6)
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.13 umap-learn-0.5.7

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from umap import UMAP
from sklearn.metrics.pairwise import manhattan_distances

# %%
df = pd.read_csv("C:/Users/Paolo/Documents/Bioinformatics Research/Khomtchouk Lab/Aachen University/MA_VC_Study/MIMIC_III_VC.csv")

# %%
df = df.dropna()

# %%
dissimilarities = manhattan_distances(df.iloc[:,1:6])

# %%
dissimilarities.shape
# Out:
# (24859, 24859)

# %%
embedding = UMAP(n_components=2, metric='manhattan', random_state=30).fit_transform(df.iloc[:,1:6])
# Out:
# C:\Users\Paolo\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=df['MA'])
plt.title('Metabolic Acidosis Data UMAP Reduction')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.grid(True)
plt.show()

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=df['VC'])
plt.title('Metabolic Acidosis Data UMAP Reduction')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.grid(True)
plt.show()
